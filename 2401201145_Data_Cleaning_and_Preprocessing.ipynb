# %% [markdown]
# ## 1. Install and Import Required Libraries

# %%
# !pip install nltk

from nltk.tokenize import word_tokenize, sent_tokenize
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# Requirement already satisfied: nltk in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.10.3)
# Requirement already satisfied: defusedxml in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk) (0.7.1)
# Requirement already satisfied: click in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk) (8.4.2)
# Requirement already satisfied: joblib in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk) (1.6.0)
# Requirement already satisfied: regex>=2021.8.3 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk) (2026.9.10)
# Requirement already satisfied: tqdm in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk) (4.70.1)
# Requirement already satisfied: colorama in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: cloudpickle>=3.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from joblib->nltk) (3.1.2)
# [nltk_data] Downloading package punkt to C:\Users\Mohd
# [nltk_data]     Shadaf\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Mohd
# [nltk_data]     Shadaf\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# ## 2. Word Tokenization
#
# Word tokenization splits a piece of text into individual words (and punctuation marks) called *tokens*.

# %%
# Word tokenizer
text = "Ram is a good cook, but he can't make pulses."
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['Ram', 'is', 'a', 'good', 'cook', ',', 'but', 'he', 'ca', "n't", 'make', 'pulses', '.']

# %% [markdown]
# ## 3. Sentence Tokenization
#
# Sentence tokenization splits a paragraph or a document into individual sentences.

# %%
# Sentence tokenizer
text = """Ram is a good cook.
He is only 18 years old. His phone number is 87587668"""

sentences = sent_tokenize(text)
sentences
# Out:
# ['Ram is a good cook.',
#  'He is only 18 years old.',
#  'His phone number is 87587668']

# %% [markdown]
# ## 4. Removing Punctuations
#
# Punctuation marks usually do not add meaning to text analysis, so they are commonly removed during preprocessing.

# %%
# Removing punctuations
import string

text = "he is ^%#$ and full of life ?<(*&"
tokens = word_tokenize(text)
print("Before removing punctuations:", tokens)

words = []
for i in tokens:
    if i not in string.punctuation:
        words.append(i)

print("After removing punctuations:", words)
# Out:
# Before removing punctuations: ['he', 'is', '^', '%', '#', '$', 'and', 'full', 'of', 'life', '?', '<', '(', '*', '&']
# After removing punctuations: ['he', 'is', 'and', 'full', 'of', 'life']

# %% [markdown]
# ## 5. Stop Word Removal
#
# Stop words (like "is", "a", "but", "he") are extremely common words that usually carry little useful information for many NLP tasks, so they are often removed.

# %%
# Stop word removal
from nltk.corpus import stopwords
nltk.download('stopwords')

text = "Ram is a good cook, but he can not make pulses."
tokens = word_tokenize(text)

words = []
for i in tokens:
    if i.lower() not in stopwords.words('english'):
        words.append(i)

print("Before removing stopwords:", tokens)
print("After removing stopwords:", words)
# Out:
# Before removing stopwords: ['Ram', 'is', 'a', 'good', 'cook', ',', 'but', 'he', 'can', 'not', 'make', 'pulses', '.']
# After removing stopwords: ['Ram', 'good', 'cook', ',', 'make', 'pulses', '.']
# [nltk_data] Downloading package stopwords to C:\Users\Mohd
# [nltk_data]     Shadaf\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## 6. Spelling Correction using `pyspellchecker`
#
# Real-world text data (chats, reviews, tweets) often contains spelling mistakes. The `pyspellchecker` library can be used to automatically correct such words.

# %%
# Spelling Checking - Method 1: pyspellchecker
# !pip install pyspellchecker
from spellchecker import SpellChecker

spell = SpellChecker()

text = "i havv a gud, bd, and ugly situton"
tokens = text.split()

correct = []
for i in tokens:
    correct.append(spell.correction(i))

print("Before correction:", tokens)
print("After correction:", correct)
# Out:
# Collecting pyspellchecker
#   Using cached pyspellchecker-0.9.0-py3-none-any.whl.metadata (9.3 kB)
# Downloading pyspellchecker-0.9.0-py3-none-any.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7
#    ------------------------------------- -- 6.8/7.2 MB 208.8 kB/s eta 0:00:03
#    ------------------------------------- -- 6.8/7.2 MB 208.8 kB/s eta 0:00:03
#    ------------------------------------- -- 6.8/7.2 MB 208.8 kB/s eta 0:00:03
#    ------------------------------------- -- 6.8/7.2 MB 208.8 kB/s eta 0:00:03
#    ------------------------------------- -- 6.8/7.2 MB 208.8 kB/s eta 0:00:03
#    ---------------------------------------  7.1/7.2 MB 208.2 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 208.2 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 208.2 kB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 208.5 kB/s  0:00:36
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.9.0
# Before correction: ['i', 'havv', 'a', 'gud,', 'bd,', 'and', 'ugly', 'situton']
# After correction: ['i', 'have', 'a', 'guys', 'be', 'and', 'ugly', 'situation']

# %% [markdown]
# ## 7. Spelling Correction using `TextBlob`
#
# `TextBlob` provides another simple way to correct spelling mistakes, this time by correcting the entire string at once instead of word by word.

# %%
# Spelling Checking - Method 2: TextBlob
# !pip install textblob
from textblob import TextBlob

text = "i havv bot godd fod"
corrected = str(TextBlob(text).correct())

print("Before correction:", text)
print("After correction:", corrected)
# Out:
# Collecting textblob
#   Downloading textblob-0.20.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: nltk>=3.9 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from textblob) (3.10.3)
# Requirement already satisfied: defusedxml in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk>=3.9->textblob) (0.7.1)
# Requirement already satisfied: click in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk>=3.9->textblob) (8.4.2)
# Requirement already satisfied: joblib in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk>=3.9->textblob) (1.6.0)
# Requirement already satisfied: regex>=2021.8.3 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk>=3.9->textblob) (2026.9.10)
# Requirement already satisfied: tqdm in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk>=3.9->textblob) (4.70.1)
# Requirement already satisfied: colorama in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Requirement already satisfied: cloudpickle>=3.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from joblib->nltk>=3.9->textblob) (3.1.2)
# Downloading textblob-0.20.1-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/625.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/625.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/625.0 kB ? eta -:--:--
#    ------------------------------- ------ 524.3/625.0 kB 385.8 kB/s eta 0:00:01
#    ---------------------------------------- 625.0/625.0 kB 404.5 kB/s  0:00:01
# Installing collected packages: textblob
# Successfully installed textblob-0.20.1
# Before correction: i havv bot godd fod
# After correction: i have not good for

# %% [markdown]
# ## 8. Putting It All Together — A Simple Preprocessing Pipeline
#
# The function below combines all the previous steps: spelling correction, tokenization, punctuation removal, and stop word removal.

# %%
from spellchecker import SpellChecker
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string

spell = SpellChecker()

def preprocess_text(text):
    # Step 1: Tokenize
    tokens = word_tokenize(text)

    # Step 2: Correct spelling
    tokens = [spell.correction(word) if spell.correction(word) else word for word in tokens]

    # Step 3: Remove punctuation
    tokens = [word for word in tokens if word not in string.punctuation]

    # Step 4: Remove stop words
    tokens = [word for word in tokens if word.lower() not in stopwords.words('english')]

    return tokens


sample_text = "Ram is a gud cook, but he can't makke pulses!!"
cleaned_tokens = preprocess_text(sample_text)

print("Original text:", sample_text)
print("Cleaned tokens:", cleaned_tokens)
# Out:
# Original text: Ram is a gud cook, but he can't makke pulses!!
# Cleaned tokens: ['Ram', 'guy', 'cook', 'ca', 'make', 'pulses']
